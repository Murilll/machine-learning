# %% [markdown]
# <a href="https://colab.research.google.com/github/Murilll/machine-learning/blob/main/Ol%C3%A1%2C_este_%C3%A9_o_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U scikit-learn
# !pip install pandas
# !pip install joblib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 69.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ...

# %%
from sklearn.datasets import load_diabetes
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from joblib import load, dump

# %%
import pandas as pd

dataset = pd.read_csv("heart_failure_clinical_records_dataset.csv")

data = dataset[['age', 'smoking', 'diabetes', 'anaemia']]
target = dataset["DEATH_EVENT"]

X = pd.DataFrame(data)
Y = pd.DataFrame(target)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=120)

model = DecisionTreeClassifier(max_depth=12, min_samples_split=10)
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=12, min_samples_split=10)

# %%
Y_pred = model.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print(accuracy)
# Out:
# 0.6166666666666667

# %%
plot_tree(model)
confusion_matrix(Y_test, Y_pred)
# Out:
# array([[30, 13],
#        [10,  7]])

# %%
from sklearn.datasets import load_diabetes
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from joblib import load, dump

import pandas as pd

dataset = pd.read_csv("seattle-weather.csv")

data = dataset[['precipitation', 'temp_max', 'temp_min', 'wind']]
target = dataset["weather"]

X = pd.DataFrame(data)
Y = pd.DataFrame(target)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=120)

model = DecisionTreeClassifier(max_depth=12, min_samples_split=10)
model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print(accuracy)

plot_tree(model)
confusion_matrix(Y_test, Y_pred)
# Out:
# 0.7781569965870307
# array([[  1,   0,   0,   0,   9],
#        [  2,   6,   0,   0,  13],
#        [  0,   0, 120,   1,   8],
#        [  0,   0,   4,   4,   0],
#        [  6,  16,   6,   0,  97]])
